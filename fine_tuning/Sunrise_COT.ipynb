# %% [markdown]
# ### Install and Import Packages

# %%
# !pip install -r ..\requirements.txt
# Out:
# Requirement already satisfied: ipykernel in c:\users\ivan ng\appdata\roaming\python\python312\site-packages (from -r ..\requirements.txt (line 1)) (6.29.5)
# Requirement already satisfied: PyPDF2 in d:\anaconda3\lib\site-packages (from -r ..\requirements.txt (line 2)) (3.0.1)
# Requirement already satisfied: chromadb in d:\anaconda3\lib\site-packages (from -r ..\requirements.txt (line 3)) (1.0.12)
# Requirement already satisfied: transformers in d:\anaconda3\lib\site-packages (from -r ..\requirements.txt (line 4)) (4.52.4)
# Requirement already satisfied: torch in d:\anaconda3\lib\site-packages (from -r ..\requirements.txt (line 5)) (2.7.0+cu126)
# Requirement already satisfied: numpy in d:\anaconda3\lib\site-packages (from -r ..\requirements.txt (line 6)) (1.26.4)
# Requirement already satisfied: pandas in d:\anaconda3\lib\site-packages (from -r ..\requirements.txt (line 7)) (2.2.3)
# Requirement already satisfied: sentence_transformers in d:\anaconda3\lib\site-packages (from -r ..\requirements.txt (line 8)) (4.1.0)
# Requirement already satisfied: peft in d:\anaconda3\lib\site-packages (from -r ..\requirements.txt (line 9)) (0.15.2)
# Requirement already satisfied: accelerate in d:\anaconda3\lib\site-packages (from -r ..\requirements.txt (line 10)) (1.7.0)
# Requirement already satisfied: bitsandbytes in d:\anaconda3\lib\site-packages (from -r ..\requirements.txt (line 11)) (0.46.0)
# Requirement already satisfied: datasets in d:\anaconda3\lib\site-packages (from -r ..\requirements.txt (line 12)) (3.6.0)
# Requirement already satisfied: langchain in d:\anaconda3\lib\site-packages (from -r ..\requirements.txt (line 13)) (0.3.25)
# Requirement already satisfied: langchain-core in d:\anaconda3\lib\site-packages (from -r ..\requirements.txt (line 14)) (0.3.63)
# Requirement already satisfied: comm>=0.1.1 in c:\users\ivan ng\appdata\roaming\python\python312\site-packages (from ipykernel->-r ..\requirements.txt (line 1)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\ivan ng\appdata\roaming\python\python312\site-packages (from ipykernel->-r ..\requirements.txt (line 1)) (1.8.14)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\ivan ng\appdata\roaming\python\python312\site-packages (from ipykernel->-r ..\requirements.txt (line 1)) (9.2.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\ivan ng\appdata\roaming\python\python312\site-packages (from ipykernel->-r ..\requirements.txt (line 1)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\ivan ng\appdata\roaming\python\python312\site-packages (from ipykernel->-r ..\requirements.txt (line 1)) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\ivan ng\appdata\roaming\python\python312\site-packages (from ipykernel->-r ..\requirements.txt (line 1)) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\ivan ng\appdata\roaming\python\python312\site-packages (from ipykernel->-r ..\requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: packaging in d:\anaconda3\lib\site-packages (from ipykernel->-r ..\requirements.txt (line 1)) (24.1)
# Requirement already satisfied: psutil in c:\users\ivan ng\appdata\roaming\python\python312\site-packages (from ipykernel->-r ..\requirements.txt (line 1)) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\ivan ng\appdata\roaming\python\python312\site-packages (from ipykernel->-r ..\requirements.txt (line 1)) (26.4.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\ivan ng\appdata\roaming\python\python312\site-packages (from ipykernel->-r ..\requirements.txt (line 1)) (6.5.1)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\ivan ng\appdata\roaming\python\python312\site-packages (from ipykernel->-r ..\requirements.txt (line 1)) (5.14.3)
# Requirement already satisfied: build>=1.0.3 in d:\anaconda3\lib\site-packages (from chromadb->-r ..\requirements.txt (line 3)) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in d:\anaconda3\lib\site-packages (from chromadb->-r ..\requirements.txt (line 3)) (2.11.5)
# Requirement already satisfied: fastapi==0.115.9 in d:\anaconda3\lib\site-packages (from chromadb->-r ..\requirements.txt (line 3)) (0.115.9)
# Requirement already satisfied: uvicorn>=0.18.3 in d:\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r ..\requirements.txt (line 3)) (0.34.3)
# Requirement already satisfied: posthog>=2.4.0 in d:\anaconda3\lib\site-packages (from chromadb->-r ..\requirements.txt (line 3)) (4.2.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in d:\anaconda3\lib\site-packages (from chromadb->-r ..\requirements.txt (line 3)) (4.14.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in d:\anaconda3\lib\site-packages (from chromadb->-r ..\requirements.txt (line 3)) (1.22.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in d:\anaconda3\lib\site-packages (from chromadb->-r ..\requirements.txt (line 3)) (1.33.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in d:\anaconda3\lib\site-packages (from chromadb->-r ..\requirements.txt (line 3)) (1.33.1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in d:\anaconda3\lib\site-packages (from chromadb->-r ..\requirements.txt (line 3)) (0.54b1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in d:\anaconda3\lib\site-packages (from chromadb->-r ..\requirements.txt (line 3)) (1.33.1)
# Requirement already satisfied: tokenizers>=0.13.2 in d:\anaconda3\lib\site-packages (from chromadb->-r ..\requirements.txt (line 3)) (0.21.1)
# Requirement already satisfied: pypika>=0.48.9 in d:\anaconda3\lib\site-packages (from chromadb->-r ..\requirements.txt (line 3)) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in d:\anaconda3\lib\site-packages (from chromadb->-r ..\requirements.txt (line 3)) (4.66.5)
# Requirement already satisfied: overrides>=7.3.1 in d:\anaconda3\lib\site-packages (from chromadb->-r ..\requirements.txt (line 3)) (7.4.0)
# Requirement already satisfied: importlib-resources in d:\anaconda3\lib\site-packages (from chromadb->-r ..\requirements.txt (line 3)) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in d:\anaconda3\lib\site-packages (from chromadb->-r ..\requirements.txt (line 3)) (1.72.1)
# Requirement already satisfied: bcrypt>=4.0.1 in d:\anaconda3\lib\site-packages (from chromadb->-r ..\requirements.txt (line 3)) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in d:\anaconda3\lib\site-packages (from chromadb->-r ..\requirements.txt (line 3)) (0.16.0)
# Requirement already satisfied: kubernetes>=28.1.0 in d:\anaconda3\lib\site-packages (from chromadb->-r ..\requirements.txt (line 3)) (32.0.1)
# Requirement already satisfied: tenacity>=8.2.3 in d:\anaconda3\lib\site-packages (from chromadb->-r ..\requirements.txt (line 3)) (8.2.3)
# Requirement already satisfied: pyyaml>=6.0.0 in d:\anaconda3\lib\site-packages (from chromadb->-r ..\requirements.txt (line 3)) (6.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in d:\anaconda3\lib\site-packages (from chromadb->-r ..\requirements.txt (line 3)) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in d:\anaconda3\lib\site-packages (from chromadb->-r ..\requirements.txt (line 3)) (3.10.18)
# Requirement already satisfied: httpx>=0.27.0 in d:\anaconda3\lib\site-packages (from chromadb->-r ..\requirements.txt (line 3)) (0.27.0)
# Requirement already satisfied: rich>=10.11.0 in d:\anaconda3\lib\site-packages (from chromadb->-r ..\requirements.txt (line 3)) (14.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in d:\anaconda3\lib\site-packages (from chromadb->-r ..\requirements.txt (line 3)) (4.23.0)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in d:\anaconda3\lib\site-packages (from fastapi==0.115.9->chromadb->-r ..\requirements.txt (line 3)) (0.45.3)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb->-r ..\requirements.txt (line 3)) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in d:\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb->-r ..\requirements.txt (line 3)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in d:\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb->-r ..\requirements.txt (line 3)) (0.4.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in d:\anaconda3\lib\site-packages (from starlette<0.46.0,>=0.40.0->fastapi==0.115.9->chromadb->-r ..\requirements.txt (line 3)) (4.9.0)
# Requirement already satisfied: idna>=2.8 in d:\anaconda3\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.46.0,>=0.40.0->fastapi==0.115.9->chromadb->-r ..\requirements.txt (line 3)) (3.7)
# Requirement already satisfied: sniffio>=1.1 in d:\anaconda3\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.46.0,>=0.40.0->fastapi==0.115.9->chromadb->-r ..\requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: filelock in d:\anaconda3\lib\site-packages (from transformers->-r ..\requirements.txt (line 4)) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in d:\anaconda3\lib\site-packages (from transformers->-r ..\requirements.txt (line 4)) (0.32.4)
# Requirement already satisfied: regex!=2019.12.17 in d:\anaconda3\lib\site-packages (from transformers->-r ..\requirements.txt (line 4)) (2024.9.11)
# Requirement already satisfied: requests in d:\anaconda3\lib\site-packages (from transformers->-r ..\requirements.txt (line 4)) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.3 in d:\anaconda3\lib\site-packages (from transformers->-r ..\requirements.txt (line 4)) (0.5.3)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.30.0->transformers->-r ..\requirements.txt (line 4)) (2025.3.0)
# Requirement already satisfied: sympy>=1.13.3 in d:\anaconda3\lib\site-packages (from torch->-r ..\requirements.txt (line 5)) (1.13.3)
# Requirement already satisfied: networkx in d:\anaconda3\lib\site-packages (from torch->-r ..\requirements.txt (line 5)) (3.3)
# Requirement already satisfied: jinja2 in d:\anaconda3\lib\site-packages (from torch->-r ..\requirements.txt (line 5)) (3.1.4)
# Requirement already satisfied: setuptools in d:\anaconda3\lib\site-packages (from torch->-r ..\requirements.txt (line 5)) (75.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ivan ng\appdata\roaming\python\python312\site-packages (from pandas->-r ..\requirements.txt (line 7)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda3\lib\site-packages (from pandas->-r ..\requirements.txt (line 7)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\anaconda3\lib\site-packages (from pandas->-r ..\requirements.txt (line 7)) (2023.3)
# Requirement already satisfied: scikit-learn in d:\anaconda3\lib\site-packages (from sentence_transformers->-r ..\requirements.txt (line 8)) (1.6.1)
# Requirement already satisfied: scipy in d:\anaconda3\lib\site-packages (from sentence_transformers->-r ..\requirements.txt (line 8)) (1.13.1)
# Requirement already satisfied: Pillow in d:\anaconda3\lib\site-packages (from sentence_transformers->-r ..\requirements.txt (line 8)) (10.4.0)
# Requirement already satisfied: pyarrow>=15.0.0 in d:\anaconda3\lib\site-packages (from datasets->-r ..\requirements.txt (line 12)) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in d:\anaconda3\lib\site-packages (from datasets->-r ..\requirements.txt (line 12)) (0.3.8)
# Requirement already satisfied: xxhash in d:\anaconda3\lib\site-packages (from datasets->-r ..\requirements.txt (line 12)) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in d:\anaconda3\lib\site-packages (from datasets->-r ..\requirements.txt (line 12)) (0.70.16)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in d:\anaconda3\lib\site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r ..\requirements.txt (line 12)) (3.10.5)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in d:\anaconda3\lib\site-packages (from langchain->-r ..\requirements.txt (line 13)) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in d:\anaconda3\lib\site-packages (from langchain->-r ..\requirements.txt (line 13)) (0.3.44)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in d:\anaconda3\lib\site-packages (from langchain->-r ..\requirements.txt (line 13)) (2.0.34)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in d:\anaconda3\lib\site-packages (from langchain-core->-r ..\requirements.txt (line 14)) (1.33)
# Requirement already satisfied: jsonpointer>=1.9 in d:\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core->-r ..\requirements.txt (line 14)) (2.1)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in d:\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain->-r ..\requirements.txt (line 13)) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in d:\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain->-r ..\requirements.txt (line 13)) (0.23.0)
# Requirement already satisfied: certifi in d:\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb->-r ..\requirements.txt (line 3)) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in d:\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb->-r ..\requirements.txt (line 3)) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb->-r ..\requirements.txt (line 3)) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda3\lib\site-packages (from requests->transformers->-r ..\requirements.txt (line 4)) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda3\lib\site-packages (from requests->transformers->-r ..\requirements.txt (line 4)) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in d:\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain->-r ..\requirements.txt (line 13)) (3.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in d:\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r ..\requirements.txt (line 12)) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r ..\requirements.txt (line 12)) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in d:\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r ..\requirements.txt (line 12)) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r ..\requirements.txt (line 12)) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r ..\requirements.txt (line 12)) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in d:\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r ..\requirements.txt (line 12)) (1.11.0)
# Requirement already satisfied: pyproject_hooks in d:\anaconda3\lib\site-packages (from build>=1.0.3->chromadb->-r ..\requirements.txt (line 3)) (1.2.0)
# Requirement already satisfied: colorama in c:\users\ivan ng\appdata\roaming\python\python312\site-packages (from build>=1.0.3->chromadb->-r ..\requirements.txt (line 3)) (0.4.6)
# Requirement already satisfied: decorator in c:\users\ivan ng\appdata\roaming\python\python312\site-packages (from ipython>=7.23.1->ipykernel->-r ..\requirements.txt (line 1)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\ivan ng\appdata\roaming\python\python312\site-packages (from ipython>=7.23.1->ipykernel->-r ..\requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\ivan ng\appdata\roaming\python\python312\site-packages (from ipython>=7.23.1->ipykernel->-r ..\requirements.txt (line 1)) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\ivan ng\appdata\roaming\python\python312\site-packages (from ipython>=7.23.1->ipykernel->-r ..\requirements.txt (line 1)) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ivan ng\appdata\roaming\python\python312\site-packages (from ipython>=7.23.1->ipykernel->-r ..\requirements.txt (line 1)) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\ivan ng\appdata\roaming\python\python312\site-packages (from ipython>=7.23.1->ipykernel->-r ..\requirements.txt (line 1)) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\ivan ng\appdata\roaming\python\python312\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->-r ..\requirements.txt (line 1)) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\ivan ng\appdata\roaming\python\python312\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->-r ..\requirements.txt (line 1)) (0.8.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb->-r ..\requirements.txt (line 3)) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb->-r ..\requirements.txt (line 3)) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb->-r ..\requirements.txt (line 3)) (0.10.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\ivan ng\appdata\roaming\python\python312\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->-r ..\requirements.txt (line 1)) (4.3.8)
# Requirement already satisfied: pywin32>=300 in c:\users\ivan ng\appdata\roaming\python\python312\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->-r ..\requirements.txt (line 1)) (310)
# Requirement already satisfied: six>=1.9.0 in c:\users\ivan ng\appdata\roaming\python\python312\site-packages (from kubernetes>=28.1.0->chromadb->-r ..\requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: google-auth>=1.0.1 in d:\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb->-r ..\requirements.txt (line 3)) (2.40.2)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in d:\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb->-r ..\requirements.txt (line 3)) (1.8.0)
# Requirement already satisfied: requests-oauthlib in d:\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb->-r ..\requirements.txt (line 3)) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in d:\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb->-r ..\requirements.txt (line 3)) (3.2.2)
# Requirement already satisfied: durationpy>=0.7 in d:\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb->-r ..\requirements.txt (line 3)) (0.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->-r ..\requirements.txt (line 3)) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->-r ..\requirements.txt (line 3)) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->-r ..\requirements.txt (line 3)) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in d:\anaconda3\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->-r ..\requirements.txt (line 3)) (0.4.8)
# Requirement already satisfied: coloredlogs in d:\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb->-r ..\requirements.txt (line 3)) (15.0.1)
# Requirement already satisfied: flatbuffers in d:\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb->-r ..\requirements.txt (line 3)) (25.2.10)
# Requirement already satisfied: protobuf in d:\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb->-r ..\requirements.txt (line 3)) (5.29.5)
# Requirement already satisfied: deprecated>=1.2.6 in d:\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb->-r ..\requirements.txt (line 3)) (1.2.18)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in d:\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb->-r ..\requirements.txt (line 3)) (7.0.1)
# Requirement already satisfied: zipp>=0.5 in d:\anaconda3\lib\site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb->-r ..\requirements.txt (line 3)) (3.17.0)
# Requirement already satisfied: wrapt<2,>=1.10 in d:\anaconda3\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.2.0->chromadb->-r ..\requirements.txt (line 3)) (1.14.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in d:\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r ..\requirements.txt (line 3)) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.33.1 in d:\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r ..\requirements.txt (line 3)) (1.33.1)
# Requirement already satisfied: opentelemetry-proto==1.33.1 in d:\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r ..\requirements.txt (line 3)) (1.33.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.54b1 in d:\anaconda3\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb->-r ..\requirements.txt (line 3)) (0.54b1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.54b1 in d:\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->-r ..\requirements.txt (line 3)) (0.54b1)
# Requirement already satisfied: opentelemetry-instrumentation==0.54b1 in d:\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->-r ..\requirements.txt (line 3)) (0.54b1)
# Requirement already satisfied: opentelemetry-util-http==0.54b1 in d:\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->-r ..\requirements.txt (line 3)) (0.54b1)
# Requirement already satisfied: asgiref~=3.0 in d:\anaconda3\lib\site-packages (from opentelemetry-instrumentation-asgi==0.54b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->-r ..\requirements.txt (line 3)) (3.8.1)
# Requirement already satisfied: backoff>=1.10.0 in d:\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb->-r ..\requirements.txt (line 3)) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in d:\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb->-r ..\requirements.txt (line 3)) (1.9.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb->-r ..\requirements.txt (line 3)) (2.2.0)
# Requirement already satisfied: mdurl~=0.1 in d:\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb->-r ..\requirements.txt (line 3)) (0.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\anaconda3\lib\site-packages (from sympy>=1.13.3->torch->-r ..\requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: click>=8.0.0 in d:\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb->-r ..\requirements.txt (line 3)) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in d:\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb->-r ..\requirements.txt (line 3)) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in d:\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r ..\requirements.txt (line 3)) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in d:\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r ..\requirements.txt (line 3)) (1.1.0)
# Requirement already satisfied: watchfiles>=0.13 in d:\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r ..\requirements.txt (line 3)) (1.0.5)
# Requirement already satisfied: websockets>=10.4 in d:\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r ..\requirements.txt (line 3)) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in d:\anaconda3\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb->-r ..\requirements.txt (line 3)) (10.0)
# Requirement already satisfied: pyreadline3 in d:\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb->-r ..\requirements.txt (line 3)) (3.5.4)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda3\lib\site-packages (from jinja2->torch->-r ..\requirements.txt (line 5)) (2.1.3)
# Requirement already satisfied: joblib>=1.2.0 in d:\anaconda3\lib\site-packages (from scikit-learn->sentence_transformers->-r ..\requirements.txt (line 8)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\anaconda3\lib\site-packages (from scikit-learn->sentence_transformers->-r ..\requirements.txt (line 8)) (3.5.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\ivan ng\appdata\roaming\python\python312\site-packages (from stack_data->ipython>=7.23.1->ipykernel->-r ..\requirements.txt (line 1)) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\ivan ng\appdata\roaming\python\python312\site-packages (from stack_data->ipython>=7.23.1->ipykernel->-r ..\requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\ivan ng\appdata\roaming\python\python312\site-packages (from stack_data->ipython>=7.23.1->ipykernel->-r ..\requirements.txt (line 1)) (0.2.3)

# %%
import json
import random
import pandas as pd
from sklearn.model_selection import train_test_split
from datasets import load_dataset
from collections import Counter, defaultdict

# %% [markdown]
# ### Data Loading

# %%
sunrise_path = "fine_tuning_sunrise.json"

# %%
dataset = load_dataset('json', data_files=sunrise_path)
dataset
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'type', 'chapter', 'set', 'question', 'answer'],
#         num_rows: 600
#     })
# })

# %%
dataset_chapter = dataset['train']['chapter']
dataset_type = dataset['train']['type']
dataset_set = dataset['train']['set']
print(dataset_chapter)
print(dataset_type)
print(dataset_set)
# Out:
# ['Chapter 1', 'Chapter 1', 'Chapter 1', 'Chapter 1', 'Chapter 1', 'Chapter 1', 'Chapter 1', 'Chapter 1', 'Chapter 1', 'Chapter 1', 'Chapter 1', 'Chapter 1', 'Chapter 1', 'Chapter 1', 'Chapter 1', 'Chapter 1', 'Chapter 1', 'Chapter 1', 'Chapter 1', 'Chapter 1', 'Chapter 2', 'Chapter 2', 'Chapter 2', 'Chapter 2', 'Chapter 2', 'Chapter 2', 'Chapter 2', 'Chapter 2', 'Chapter 2', 'Chapter 2', 'Chapter 2', 'Chapter 2', 'Chapter 2', 'Chapter 2', 'Chapter 2', 'Chapter 2', 'Chapter 2', 'Chapter 2', 'Chapter 2', 'Chapter 2', 'Chapter 3', 'Chapter 3', 'Chapter 3', 'Chapter 3', 'Chapter 3', 'Chapter 3', 'Chapter 3', 'Chapter 3', 'Chapter 3', 'Chapter 3', 'Chapter 3', 'Chapter 3', 'Chapter 3', 'Chapter 3', 'Chapter 3', 'Chapter 3', 'Chapter 3', 'Chapter 3', 'Chapter 3', 'Chapter 3', 'Chapter 4', 'Chapter 4', 'Chapter 4', 'Chapter 4', 'Chapter 4', 'Chapter 4', 'Chapter 4', 'Chapter 4', 'Chapter 4', 'Chapter 4', 'Chapter 4', 'Chapter 4', 'Chapter 4', 'Chapter 4', 'Chapter 4', 'Chapter 4', 'Chapter 4', 'Chapter 4', 'Chapter 4', 'Chapter 4', 'Chapter 5', 'Chapter 5', 'Chapter 5', 'Chapter 5', 'Chapter 5', 'Chapter 5', 'Chapter 5', 'Chapter 5', 'Chapter 5', 'Chapter 5', 'Chapter 5', 'Chapter 5', 'Chapter 5', 'Chapter 5', 'Chapter 5', 'Chapter 5', 'Chapter 5', 'Chapter 5', 'Chapter 5', 'Chapter 5', 'Chapter 6', 'Chapter 6', 'Chapter 6', 'Chapter 6', 'Chapter 6', 'Chapter 6', 'Chapter 6', 'Chapter 6', 'Chapter 6', 'Chapter 6', 'Chapter 6', 'Chapter 6', 'Chapter 6', 'Chapter 6', 'Chapter 6', 'Chapter 6', 'Chapter 6', 'Chapter 6', 'Chapter 6', 'Chapter 6', 'Chapter 7', 'Chapter 7', 'Chapter 7', 'Chapter 7', 'Chapter 7', 'Chapter 7', 'Chapter 7', 'Chapter 7', 'Chapter 7', 'Chapter 7', 'Chapter 7', 'Chapter 7', 'Chapter 7', 'Chapter 7', 'Chapter 7', 'Chapter 7', 'Chapter 7', 'Chapter 7', 'Chapter 7', 'Chapter 7', 'Chapter 8', 'Chapter 8', 'Chapter 8', 'Chapter 8', 'Chapter 8', 'Chapter 8', 'Chapter 8', 'Chapter 8', 'Chapter 8', 'Chapter 8', 'Chapter 8', 'Chapter 8', 'Chapter 8', 'Chapter 8', 'Chapter 8', 'Chapter 8', 'Chapter 8', 'Chapter 8', 'Chapter 8', 'Chapter 8', 'Chapter 9', 'Chapter 9', 'Chapter 9', 'Chapter 9', 'Chapter 9', 'Chapter 9', 'Chapter 9', 'Chapter 9', 'Chapter 9', 'Chapter 9', 'Chapter 9', 'Chapter 9', 'Chapter 9', 'Chapter 9', 'Chapter 9', 'Chapter 9', 'Chapter 9', 'Chapter 9', 'Chapter 9', 'Chapter 9', 'Chapter 10', 'Chapter 10', 'Chapter 10', 'Chapter 10', 'Chapter 10', 'Chapter 10', 'Chapter 10', 'Chapter 10', 'Chapter 10', 'Chapter 10', 'Chapter 10', 'Chapter 10', 'Chapter 10', 'Chapter 10', 'Chapter 10', 'Chapter 10', 'Chapter 10', 'Chapter 10', 'Chapter 10', 'Chapter 10', 'Chapter 11', 'Chapter 11', 'Chapter 11', 'Chapter 11', 'Chapter 11', 'Chapter 11', 'Chapter 11', 'Chapter 11', 'Chapter 11', 'Chapter 11', 'Chapter 11', 'Chapter 11', 'Chapter 11', 'Chapter 11', 'Chapter 11', 'Chapter 11', 'Chapter 11', 'Chapter 11', 'Chapter 11', 'Chapter 11', 'Chapter 12', 'Chapter 12', 'Chapter 12', 'Chapter 12', 'Chapter 12', 'Chapter 12', 'Chapter 12', 'Chapter 12', 'Chapter 12', 'Chapter 12', 'Chapter 12', 'Chapter 12', 'Chapter 12', 'Chapter 12', 'Chapter 12', 'Chapter 12', 'Chapter 12', 'Chapter 12', 'Chapter 12', 'Chapter 12', 'Chapter 13', 'Chapter 13', 'Chapter 13', 'Chapter 13', 'Chapter 13', 'Chapter 13', 'Chapter 13', 'Chapter 13', 'Chapter 13', 'Chapter 13', 'Chapter 13', 'Chapter 13', 'Chapter 13', 'Chapter 13', 'Chapter 13', 'Chapter 13', 'Chapter 13', 'Chapter 13', 'Chapter 13', 'Chapter 13', 'Chapter 14', 'Chapter 14', 'Chapter 14', 'Chapter 14', 'Chapter 14', 'Chapter 14', 'Chapter 14', 'Chapter 14', 'Chapter 14', 'Chapter 14', 'Chapter 14', 'Chapter 14', 'Chapter 14', 'Chapter 14', 'Chapter 14', 'Chapter 14', 'Chapter 14', 'Chapter 14', 'Chapter 14', 'Chapter 14', 'Chapter 15', 'Chapter 15', 'Chapter 15', 'Chapter 15', 'Chapter 15', 'Chapter 15', 'Chapter 15', 'Chapter 15', 'Chapter 15', 'Chapter 15', 'Chapter 15', 'Chapter 15', 'Chapter 15', 'Chapter 15', 'Chapter 15', 'Chapter 15', 'Chapter 15', 'Chapter 15', 'Chapte ...
# ['Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Summary & Inference', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Detail Extraction', 'Summary & Inference', 'Summary & Infer ...
# ['training', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'validation', 'testing', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'validation', 'testing', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'validation', 'testing', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'validation', 'testing', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'validation', 'testing', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'validation', 'testing', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'validation', 'testing', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'validation', 'testing', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'validation', 'testing', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'validation', 'testing', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'validation', 'testing', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'validation', 'testing', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'validation', 'testing', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'validation', 'testing', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'validation', 'testing', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'validation', 'testing', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'validation', 'testing', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'validation', 'testing', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'validation', 'testing', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'validation', 'testing', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'validation', 'testing', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'validation', 'testing', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'validation', 'testing', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'validation', 'testing', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'validation', 'testing', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'validation', 'testing', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'validation', 'testing', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'validation', 'testing', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'validation', 'testing', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'validation', 'testing', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'validation', 'testing', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'validation', 'testing', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'training', 'validation', 'testing', 'train ...

# %%
chapter_counts  = {}
for chapter in dataset_chapter:
    chapter_counts[chapter] = chapter_counts.get(chapter, 0) + 1
print(chapter_counts)
# Out:
# {'Chapter 1': 20, 'Chapter 2': 20, 'Chapter 3': 20, 'Chapter 4': 20, 'Chapter 5': 20, 'Chapter 6': 20, 'Chapter 7': 20, 'Chapter 8': 20, 'Chapter 9': 20, 'Chapter 10': 20, 'Chapter 11': 20, 'Chapter 12': 20, 'Chapter 13': 20, 'Chapter 14': 20, 'Chapter 15': 20, 'Chapter 16': 20, 'Chapter 17': 20, 'Chapter 18': 20, 'Chapter 19': 20, 'Chapter 20': 20, 'Chapter 21': 20, 'Chapter 22': 20, 'Chapter 23': 20, 'Chapter 24': 20, 'Chapter 25': 20, 'Chapter 26': 20, 'Chapter 27': 20, 'Chapter 28': 20, 'Full Book': 40}

# %%
type_counts  = {}
for type in dataset_type:
    type_counts[type] = type_counts.get(type, 0) + 1
print(type_counts)
# Out:
# {'Summary & Inference': 300, 'Detail Extraction': 300}

# %%
set_counts  = {}
for set in dataset_set:
    set_counts[set] = set_counts.get(set, 0) + 1
print(set_counts)
# Out:
# {'training': 480, 'validation': 60, 'testing': 60}

# %% [markdown]
# ### Data Splitting

# %%
tuning_set = dataset['train']
tuning_set
# Out:
# Dataset({
#     features: ['id', 'type', 'chapter', 'set', 'question', 'answer'],
#     num_rows: 600
# })

# %%
tuning_set = dataset['train']
tuning_df = pd.DataFrame(
    {
        'Set':tuning_set['set'],
        'Question': tuning_set['question'],
        'Answer':[answer['final_answer'] for answer in tuning_set['answer']],
        'Reasoning': [cot['chain_of_thought'] for cot in tuning_set['answer']],
    }
)
tuning_df
# Out:
#             Set                                           Question  \
# 0      training  What is Haymitch's initial attitude towards hi...
# 1      training  Haymitch plans to spend his afternoon after fi...
# 2      training  How does Lenore Dove's perspective on the Mead...
# 3      training  Lenore Dove's name is explained by her, connec...
# 4      training  Haymitch states, 'I didn't say it was just bec...
# ..          ...                                                ...
# 595    training  What is the symbolic implication of the 'mecha...
# 596  validation  What specific item is Maysilee seen using to r...
# 597  validation  What is the nickname for the Capitol store bee...
# 598     testing  What is the primary method of movement for the...
# 599     testing  What are the two specific items of jewelry tha...
#
#                                                 Answer  \
# 0    Haymitch initially views the upside of his bir...
# 1    Haymitch hopes to devote his afternoon to 'was...
# 2    While 'most people comment on its beauty' , Le...
# 3    Lenore Dove explains her name by saying 'Dove ...
# 4    Lenore Dove accuses Haymitch of faulty logic, ...
# ..                                                 ...
# 595  The 'mechanical buzz of protest' from below af...
# 596  Maysilee uses 'a wince' and her fingers to rem...
# 597  The nickname for the Capitol store beer that H...
# 598  The squirrel mutts primarily move by 'bouncing...
# 599  Maysilee and Merrilee received 'pure gold pins...
#
#                                              Reasoning
# 0    [Identify Haymitch's initial feeling about his...
# 1    [Identify the two things Haymitch loves doing:...
# 2    [Identify how 'most people' view the Meadow: T...
# 3    [Recall Lenore Dove's explanation of her name:...
# 4    [Identify Lenore Dove's logical argument: 'You...
# ..                                                 ...
# 595  [Identify the sound: 'A mechanical buzz of pro...
# 596  [Locate the scene after the ladybug attack whe...
# 597  [Locate the scene where Haymitch is brainstorm...
# 598  [Locate the description of the squirrel mutts....
# 599  [Locate the description of Maysilee and Merril...
#
# [600 rows x 4 columns]

# %%
training_df = tuning_df[tuning_df['Set'] == 'training']
val_df = tuning_df[tuning_df['Set'] == 'validation']
test_df = tuning_df[tuning_df['Set'] == 'testing']

training_df.drop(columns = ['Set'], inplace= True)
training_df.reset_index(inplace=True)
training_df.drop(columns = ['index'], inplace= True)

val_df.drop(columns = ['Set'], inplace= True)
val_df.reset_index(inplace=True)
val_df.drop(columns = ['index'], inplace= True)

test_df.drop(columns = ['Set'], inplace= True)
test_df.reset_index(inplace=True)
test_df.drop(columns = ['index'], inplace= True)
# Out:
# C:\Users\Ivan NG\AppData\Local\Temp\ipykernel_30816\3031488639.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training_df.drop(columns = ['Set'], inplace= True)
# C:\Users\Ivan NG\AppData\Local\Temp\ipykernel_30816\3031488639.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training_df.drop(columns = ['index'], inplace= True)
# C:\Users\Ivan NG\AppData\Local\Temp\ipykernel_30816\3031488639.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_df.drop(columns = ['Set'], inplace= True)
# C:\Users\Ivan NG\AppData\Local\Temp\ipykernel_30816\3031488639.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_df.drop(columns = ['index'], inplace= True)
# C:\Users\Ivan NG\AppData\Local\Temp\ipykernel_30816\3031488639.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df.drop(columns = ['Set'], inplace= True)
# C:\Users\Ivan NG\AppData\Local\Temp\ipykernel_30816\3031488639.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df.drop(columns = ['index'], inplace= True)

# %%
training_df
# Out:
#                                               Question  \
# 0    What is Haymitch's initial attitude towards hi...
# 1    Haymitch plans to spend his afternoon after fi...
# 2    How does Lenore Dove's perspective on the Mead...
# 3    Lenore Dove's name is explained by her, connec...
# 4    Haymitch states, 'I didn't say it was just bec...
# ..                                                 ...
# 475  What are the approximate dimensions (diameter ...
# 476  What specific advice did Mamaw give about char...
# 477  What is the specific color and pattern of Drus...
# 478  What specific item is Maysilee wearing that is...
# 479  What is the symbolic implication of the 'mecha...
#
#                                                 Answer  \
# 0    Haymitch initially views the upside of his bir...
# 1    Haymitch hopes to devote his afternoon to 'was...
# 2    While 'most people comment on its beauty' , Le...
# 3    Lenore Dove explains her name by saying 'Dove ...
# 4    Lenore Dove accuses Haymitch of faulty logic, ...
# ..                                                 ...
# 475  The berms observed by Haymitch are 'about eigh...
# 476  Mamaw's specific advice about charcoal tablets...
# 477  Drusilla's jumpsuit during the interviews is '...
# 478  The 'braided cord' from Maysilee's token neckl...
# 479  The 'mechanical buzz of protest' from below af...
#
#                                              Reasoning
# 0    [Identify Haymitch's initial feeling about his...
# 1    [Identify the two things Haymitch loves doing:...
# 2    [Identify how 'most people' view the Meadow: T...
# 3    [Recall Lenore Dove's explanation of her name:...
# 4    [Identify Lenore Dove's logical argument: 'You...
# ..                                                 ...
# 475  [Locate Haymitch's examination of the berms., ...
# 476  [Locate the flashback to Mamaw and charcoal ta...
# 477  [Locate the description of Drusilla's outfit d...
# 478  [Locate the scene where Haymitch unravels Mays...
# 479  [Identify the sound: 'A mechanical buzz of pro...
#
# [480 rows x 3 columns]

# %%
val_df
# Out:
#                                              Question  \
# 0   What is the implied psychological manipulation...
# 1   What is the primary product of District 12's i...
# 2   When Maysilee throws a literal punch at Drusil...
# 3   What is the name of the District 3 victor who ...
# 4   Haymitch believes that 'Woodbine no longer see...
# 5   What is the name of the District 3 victor who ...
# 6   What is the implied effect of the Gamemakers' ...
# 7   What is the specific material used to coat the...
# 8   What is the implied purpose of the Capitol col...
# 9   What color are the District 3 tributes' outfit...
# 10  Maysilee states that she and the other tribute...
# 11  What is Maysilee's specific nickname for Haymi...
# 12  How does Maysilee's comment, 'You look like yo...
# 13  What is the name of the Head Gamemaker and wha...
# 14  When Maysilee says, 'You could reject their bu...
# 15  What two liquids are said to flow from Preside...
# 16  What is the implied deeper purpose behind the ...
# 17  What is the distinguishing feature of the plan...
# 18  How does Haymitch's internal struggle with the...
# 19  What is the primary material of the beds in th...
# 20  What is the implied psychological effect of th...
# 21  What specific advice did Mamaw give about char...
# 22  Haymitch plans to portray himself as a 'selfis...
# 23  What is the specific material used to coat the...
# 24  Haymitch observes that the Gamemakers 'must ha...
# 25  What specific item is Maysilee using to make h...
# 26  Haymitch gives Maysilee a small plastic packet...
# 27  What specific warning does Maysilee give to he...
# 28  Haymitch observes that the Gamemakers' control...
# 29  What specific advice did Mamaw give about char...
# 30  What is the implied purpose of the utility pip...
# 31  What specific advice did Mamaw give about char...
# 32  What is the symbolic implication of the 'mecha...
# 33  What is the symbolic implication of the 'mecha...
# 34  What is the symbolic implication of the 'mecha...
# 35  What is the symbolic implication of the 'mecha...
# 36  What is the primary content of the District 12...
# 37  What is the primary material of the beds in th...
# 38  What is the implied deeper purpose behind the ...
# 39  What is the primary material of the beds in th...
# 40  Maysilee states, 'One of us has to be the wors...
# 41  What is Maysilee's specific nickname for the t...
# 42  What is the symbolic implication of the 'straw...
# 43  What is the specific advice given to tributes ...
# 44  Maysilee states, 'One of us has to be the wors...
# 45  What is the specific item that Haymitch attach...
# 46  Haymitch recognizes the humming from the fores...
# 47  What is the primary material of the beds in th...
# 48  Haymitch recognizes the humming from the fores...
# 49  What is the primary material of the beds in th...
# 50  Haymitch recognizes the humming from the fores...
# 51  What is the primary material of the beds in th...
# 52  The Victor's Village house in District 12 is d...
# 53  What is the primary material of the beds in th...
# 54  Haymitch reflects on his relationship with Kat...
# 55  What is the primary material of the beds in th...
# 56  How do the 'tokens' brought by tributes from t...
# 57  The various forms of 'water' in the arena—pois...
# 58  What specific item is Maysilee seen using to r...
# 59  What is the nickname for the Capitol store bee...
#
#                                                Answer  \
# 0   The Capitol uses a 'five-minute hold on the br...
# 1   The primary product of District 12's industry ...
# 2   When Maysilee throws a literal 'wallop'  back ...
# 3   The District 3 victor who won the previous Hun...
# 4   Haymitch's dark reflection that 'Woodbine no l...
# 5   The District 3 victor who is Ampert's father i...
# 6   The Gamemakers' unprecedented decision to give...
# 7   The District 9 sunflower tokens are 'coated wi...
# 8   The implied purpose of the Capitol collecting ...
# 9   The District 3 tributes' outfits are 'electric...
# 10  Maysilee's statement, 'We never, none of us, h...
# 11  When Haymitch was six and had chiggers, Maysil...
# 12  Maysilee's comment, 'You look like you jumped ...
# 13  The Head Gamemaker is named 'Faustina Gripper'...
# 14  When Maysilee tells Wyatt, 'You could reject t...
# 15  When President Snow gets sick in the conservat...
# 16  The implied deeper purpose behind the Capitol'...
# 17  The 'gas plant' has 'pale purple flowers'. Whe...
# 18  Haymitch's internal struggle with 'hope' being...
# 19  The beds in the tributes' sleeping quarters on...
# 20  The implied psychological effect of the Gamema...
# 21  Mamaw's specific advice about charcoal tablets...
# 22  Haymitch plans to portray himself as a 'selfis...
# 23  The District 9 sunflower tokens are 'coated wi...
# 24  Haymitch observes the Gamemakers were 'scrambl...
# 25  Maysilee makes glue with 'flour and water and ...
# 26  Haymitch giving Maysilee the 'turn-a-potato-in...
# 27  Maysilee warns the other tributes, 'You have t...
# 28  Haymitch's understanding that the Gamemakers' ...
# 29  Mamaw's specific advice about charcoal tablets...
# 30  The implied purpose of the utility pipes and d...
# 31  Mamaw's specific advice about charcoal tablets...
# 32  The 'mechanical buzz of protest' from below af...
# 33  The 'mechanical buzz of protest' from below af...
# 34  The 'mechanical buzz of protest' from below af...
# 35  The 'mechanical buzz of protest' from below af...
# 36  The primary content of the District 12 tribute...
# 37  The beds in the tributes' sleeping quarters in...
# 38  The implied deeper purpose behind the Capitol'...
# 39  The beds in the tributes' sleeping quarters in...
# 40  Maysilee's final wish, 'One of us has to be th...
# 41  Maysilee's specific nickname for the tributes ...
# 42  The 'strawberry ice cream' and 'black coffee' ...
# 43  The specific advice for making fire to minimiz...
# 44  Maysilee's final wish, 'One of us has to be th...
# 45  Haymitch attaches the 'blowgun' to his belt wi...
# 46  Haymitch's realization that the humming comes ...
# 47  The beds in the tributes' sleeping quarters in...
# 48  Haymitch's realization that the humming comes ...
# 49  The beds in the tributes' sleeping quarters in...
# 50  Haymitch's realization that the humming comes ...
# 51  The beds in the tributes' sleeping quarters in...
# 52  The Victor's Village house in District 12 bein...
# 53  The beds in the tributes' sleeping quarters in...
# 54  Haymitch's comparison of Katniss ('She’s like ...
# 55  The beds in the tributes' sleeping quarters in...
# 56  Tributes' 'tokens' (Maysilee's medallions, Dis...
# 57  Water in the arena—from poisoned streams to th...
# 58  Maysilee uses 'a wince' and her fingers to rem...
# 59  The nickname for the Capitol store beer that H...
#
#                                             Reasoning
# 0   [Identify the explicit detail: A 'five-minute ...
# 1   [Recall details about Haymitch's father's deat...
# 2   [Recall the action: Maysilee 'slaps her right ...
# 3   [Identify the District 3 victor introduced as ...
# 4   [Recall Woodbine's death: Shot in the head try...
# 5   [Identify Ampert's father's name: 'Beetee'., C...
# 6   [Recall Haymitch's score: 'I get a one'., Reca...
# 7   [Locate the explanation about the District 9 s...
# 8   [Identify the fact: Trackers are 'electronic d...
# 9   [Locate the description of District 3 tributes...
# 10  [Recall Maysilee's background: From a 'richer ...
# 11  [Locate the flashback where Maysilee gives Hay...
# 12  [Identify the literal meaning: Drusilla's red-...
# 13  [Locate the introduction of the Head Gamemaker...
# 14  [Recall Wyatt's father's business: Taking bets...
# 15  [Locate the scene where President Snow gets si...
# 16  [Recall District 1's status: They are the 'Car...
# 17  [Locate the description of the 'gas plant' in ...
# 18  [Recall Haymitch's thought: 'Where there’s lif...
# 19  [Locate the description of the beds in the tri...
# 20  [Identify the signal: An 'electronic gong' rin...
# 21  [Locate the flashback to Mamaw and charcoal ta...
# 22  [Recall Haymitch's low score ('one') and publi...
# 23  [Locate the explanation about the District 9 s...
# 24  [Recall the edited footage: The recap is 'less...
# 25  [Locate the scene where Maysilee is repairing ...
# 26  [Recall the item: A 'turn-a-potato-into-a-ligh...
# 27  [Locate the scene where Lou Lou's condition is...
# 28  [Recall the immediate context: His own defiant...
# 29  [Locate the flashback to Mamaw and charcoal ta...
# 30  [Identify the description of Sub-A: 'a narrow ...
# 31  [Locate the flashback to Mamaw and charcoal ta...
# 32  [Identify the sound: 'A mechanical buzz of pro...
# 33  [Identify the sound: 'A mechanical buzz of pro...
# 34  [Identify the sound: 'A mechanical buzz of pro...
# 35  [Identify the sound: 'A mechanical buzz of pro...
# 36  [Locate descriptions of food in the tribute ap...
# 37  [Locate the description of the beds in the tri...
# 38  [Recall District 1's status: They are the 'Car...
# 39  [Locate the description of the beds in the tri...
# 40  [Recall her wish: 'be the worst victor in hist...
# 41  [Locate Maysilee's comments about District 12'...
# 42  [Recall the items: 'strawberry ice cream' and ...
# 43  [Locate the scene where Haymitch is preparing ...
# 44  [Recall her wish: 'be the worst victor in hist...
# 45  [Locate the scene where Haymitch is organizing...
# 46  [Recall the humming: 'A low humming emanates f...
# 47  [Locate the description of the beds in the tri...
# 48  [Recall the humming: 'A low humming emanates f...
# 49  [Locate the description of the beds in the tri...
# 50  [Recall the humming: 'A low humming emanates f...
# 51  [Locate the description of the beds in the tri...
# 52  [Identify the description: 'Grand', 'a monstro...
# 53  [Locate the description of the beds in the tri...
# 54  [Recall Haymitch's 'rascal' persona and his se...
# 55  [Locate the description of the beds in the tri...
# 56  [Recall various tokens: Maysilee's hummingbird...
# 57  [Recall dangerous water: Poisoned stream (rabb...
# 58  [Locate the scene after the ladybug attack whe...
# 59  [Locate the scene where Haymitch is brainstorm...

# %%
test_df
# Out:
#                                              Question  \
# 0   How does Haymitch's act of covering the camera...
# 1   What are the two items Haymitch gives to his m...
# 2   How does the Gamemakers' choice of Wiress and ...
# 3   What happens to the tributes' clothing after t...
# 4   What kind of 'dreams' does Haymitch have in th...
# 5   What are the two animals that form the design ...
# 6   How does Lou Lou's reaction to the 'dark cresc...
# 7   What is the primary content of the District 12...
# 8   Haymitch's act of applauding President Snow af...
# 9   What item, resembling a metal device, is Maysi...
# 10  What is the symbolic implication of Haymitch's...
# 11  What are the specific items collected by the '...
# 12  Haymitch's strategy for his interview is to be...
# 13  What is the symbolic nickname that Maysilee su...
# 14  How does Beetee's statement, 'My son is dispos...
# 15  What is the specific material used to create t...
# 16  Haymitch considers whether Plutarch is 'an all...
# 17  What is the specific color of Maysilee's dress...
# 18  Maysilee notes that the District 8 tributes ha...
# 19  What specific item is Maysilee seen using to r...
# 20  Haymitch is given charcoal tablets, which he i...
# 21  What specific part of Woodbine Chance's body i...
# 22  What is the deeper implication of Maysilee's o...
# 23  What is the specific type of bird that Lenore ...
# 24  Plutarch's final message to Haymitch before hi...
# 25  What two liquids are said to flow from Preside...
# 26  Haymitch realizes that the Gamemakers' control...
# 27  What is the specific name of the plant in Plut...
# 28  What is the symbolic significance of Haymitch'...
# 29  What are the approximate dimensions (diameter ...
# 30  Beetee states that the Capitol 'reaped him to ...
# 31  What are the approximate dimensions (diameter ...
# 32  Haymitch's howl of rage after Ampert's death i...
# 33  What is the final state of Ampert's body after...
# 34  Haymitch's howl of rage after Ampert's death i...
# 35  What is the final state of Ampert's body after...
# 36  Haymitch recognizes the humming from the fores...
# 37  What are the two specific items of jewelry tha...
# 38  Haymitch realizes that the Gamemakers' control...
# 39  What are the two specific items of jewelry tha...
# 40  When Haymitch is 'catapulted into the air' by ...
# 41  What specific item is Maysilee seen using to r...
# 42  Haymitch realizes that the Gamemakers' control...
# 43  What is the specific name of the plant that gr...
# 44  When Haymitch is 'catapulted into the air' by ...
# 45  What is the specific liquid that Maysilee uses...
# 46  What is the symbolic implication of the 'straw...
# 47  What are the two specific items of jewelry tha...
# 48  What is the symbolic implication of the 'straw...
# 49  What are the two specific items of jewelry tha...
# 50  What is the symbolic implication of the 'straw...
# 51  What are the two specific items of jewelry tha...
# 52  Haymitch repeatedly dreams of 'the Capitol peo...
# 53  What is the specific color and pattern of Drus...
# 54  Haymitch states, 'I’m not sure I’ll be here in...
# 55  What are the two specific items of jewelry tha...
# 56  How does President Snow's physical deteriorati...
# 57  How do the 'games' within the Games—from the i...
# 58  What is the primary method of movement for the...
# 59  What are the two specific items of jewelry tha...
#
#                                                Answer  \
# 0   Haymitch's act of throwing 'a towel over the c...
# 1   Before leaving for the Games, Haymitch empties...
# 2   The Gamemakers' choice of Wiress and Mags as m...
# 3   After tributes strip for the communal shower, ...
# 4   Haymitch's dreams in this chapter are of 'fear...
# 5   The golden staircase and eagle motif, found in...
# 6   Lou Lou's intense, emotional reaction to the '...
# 7   The primary content of the District 12 tribute...
# 8   Haymitch's act of applauding President Snow af...
# 9   Maysilee is seen knuckle-rolling a 'scrip coin...
# 10  Haymitch's observation that other tributes' gl...
# 11  On Saturday nights, the Booker Boys can usuall...
# 12  Haymitch's strategy to be a 'rascal' rather th...
# 13  Maysilee suggests the nickname 'Near Beer Care...
# 14  Beetee's chilling statement, 'My son is dispos...
# 15  The fake sunflower tokens for the District 9 t...
# 16  Haymitch views Plutarch ambiguously as 'an all...
# 17  Maysilee is described as looking 'fine in a ru...
# 18  Maysilee notes that District 8 tributes have '...
# 19  Maysilee uses 'a wince' and her fingers to rem...
# 20  Haymitch initially dismisses the 'charcoal tab...
# 21  The 'back of Woodbine's head' explodes when he...
# 22  Maysilee's observation, 'Maybe she loads up on...
# 23  Lenore Dove calls the 'raven' the 'biggest son...
# 24  Plutarch's statement, 'a desire for freedom is...
# 25  When President Snow gets sick in the conservat...
# 26  Haymitch's understanding that the Gamemakers' ...
# 27  The plant in Plutarch's conservatory that give...
# 28  Haymitch's observation that the arena looks li...
# 29  The berms observed by Haymitch are 'about eigh...
# 30  Beetee's desperate confession, 'They reaped hi...
# 31  The berms observed by Haymitch are 'about eigh...
# 32  Haymitch's howl of rage after Ampert's death, ...
# 33  After the squirrel mutt attack, Ampert's body ...
# 34  Haymitch's howl of rage after Ampert's death, ...
# 35  After the squirrel mutt attack, Ampert's body ...
# 36  Haymitch's realization that the humming comes ...
# 37  Maysilee and Merrilee received 'pure gold pins...
# 38  Haymitch's understanding that the Gamemakers' ...
# 39  Maysilee and Merrilee received 'pure gold pins...
# 40  When Haymitch is 'catapulted into the air' by ...
# 41  Maysilee uses 'a wince' and her fingers to rem...
# 42  Haymitch's understanding that the Gamemakers' ...
# 43  The plant that grows at the butterfly mutts' b...
# 44  When Haymitch is 'catapulted into the air' by ...
# 45  Maysilee uses 'blueberries' mashed into a 'jui...
# 46  The 'strawberry ice cream' and 'black coffee' ...
# 47  Maysilee and Merrilee received 'pure gold pins...
# 48  The 'strawberry ice cream' and 'black coffee' ...
# 49  Maysilee and Merrilee received 'pure gold pins...
# 50  The 'strawberry ice cream' and 'black coffee' ...
# 51  Maysilee and Merrilee received 'pure gold pins...
# 52  Haymitch's recurring dreams of 'the Capitol pe...
# 53  Drusilla's jumpsuit during the interviews is '...
# 54  Haymitch's statement, 'I’m not sure I’ll be he...
# 55  Maysilee and Merrilee received 'pure gold pins...
# 56  President Snow's physical deterioration (cough...
# 57  The 'games' within the Games—interviews, train...
# 58  The squirrel mutts primarily move by 'bouncing...
# 59  Maysilee and Merrilee received 'pure gold pins...
#
#                                             Reasoning
# 0   [Identify the action: Haymitch throws 'a towel...
# 1   [Locate the scene where Haymitch empties his p...
# 2   [Recall District 12's mentor situation: 'the o...
# 3   [Locate the scene where boys are told to strip...
# 4   [Identify the nature of his dreams: 'fearful t...
# 5   [Locate the description of the staircase in Pl...
# 6   [Recall Lou Lou's reaction: She stares in 'fas...
# 7   [Locate descriptions of food in the tribute ap...
# 8   [Recall Haymitch's action: He 'gesture[s] to h...
# 9   [Locate the scene where Maysilee is on the tra...
# 10  [Identify the contrast: Other tributes' horses...
# 11  [Locate the description of the Booker Boys' ga...
# 12  [Recall Drusilla's advice: 'You need to be nau...
# 13  [Locate Maysilee's suggestion for a nickname f...
# 14  [Recall Beetee's situation: He is 'too valuabl...
# 15  [Locate the description of the District 9 sunf...
# 16  [Recall Plutarch's seemingly helpful actions: ...
# 17  [Locate the description of Lenore Dove's appea...
# 18  [Recall the other districts' tokens: District ...
# 19  [Locate the scene after the ladybug attack whe...
# 20  [Recall initial dismissal: He thinks the 'char...
# 21  [Locate the description of Woodbine Chance's s...
# 22  [Recall Merrilee's behavior: She wears outfits...
# 23  [Locate the scene where Haymitch and Lenore Do...
# 24  [Recall the statement: 'a desire for freedom i...
# 25  [Locate the scene where President Snow gets si...
# 26  [Recall the immediate context: His own defiant...
# 27  [Locate the description of the plant in Plutar...
# 28  [Recall the physical description: 'The Cornuco...
# 29  [Locate Haymitch's examination of the berms., ...
# 30  [Identify Beetee's confession: 'They reaped hi...
# 31  [Locate Haymitch's examination of the berms., ...
# 32  [Recall the trigger: Ampert's horrific death b...
# 33  [Locate the description of Ampert's body after...
# 34  [Recall the trigger: Ampert's horrific death b...
# 35  [Locate the description of Ampert's body after...
# 36  [Recall the humming: 'A low humming emanates f...
# 37  [Locate the description of Maysilee and Merril...
# 38  [Recall the immediate context: His own defiant...
# 39  [Locate the description of Maysilee and Merril...
# 40  [Recall the crash: The chariot wheel collapses...
# 41  [Locate the scene after the ladybug attack whe...
# 42  [Recall the immediate context: His own defiant...
# 43  [Locate the description of the berm where the ...
# 44  [Recall the crash: The chariot wheel collapses...
# 45  [Locate the scene where Maysilee is restock he...
# 46  [Recall the items: 'strawberry ice cream' and ...
# 47  [Locate the description of Maysilee and Merril...
# 48  [Recall the items: 'strawberry ice cream' and ...
# 49  [Locate the description of Maysilee and Merril...
# 50  [Recall the items: 'strawberry ice cream' and ...
# 51  [Locate the description of Maysilee and Merril...
# 52  [Recall the 'gaudy clothes and weird makeup': ...
# 53  [Locate the description of Drusilla's outfit d...
# 54  [Recall his current health: 'My liver’s wrecke...
# 55  [Locate the description of Maysilee and Merril...
# 56  [Recall physical deterioration: He is old, cou...
# 57  [Recall examples of 'games within games': Inte...
# 58  [Locate the description of the squirrel mutts....
# 59  [Locate the description of Maysilee and Merril...

# %% [markdown]
# ### Store to JSON

# %%
# to data frame

# stroe to json files
training_df.to_json("sunrise_train_data.json", orient="records", lines=False, force_ascii=False)
val_df.to_json("sunrise_val_data.json", orient="records", lines=False, force_ascii=False)
test_df.to_json("sunrise_test_data.json", orient="records", lines=False, force_ascii=False)


print("Successfully saved train_data to train_data.json!")
print("Successfully saved val_data to val_data.json!")
print("Successfully saved test_data to test_data.json!")
# Out:
# Successfully saved train_data to train_data.json!
# Successfully saved val_data to val_data.json!
# Successfully saved test_data to test_data.json!

# %% [markdown]
# ### Load Sunrise on the Reaping
